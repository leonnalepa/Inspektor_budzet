-- %%
CREATE TABLE IF NOT EXISTS inspektor_budzet.rowkop.blueprint_pozycje (
  position_id  STRING NOT NULL,
  nazwa        STRING,
  jednostka    STRING,
  typ          STRING
)
COMMENT 'Pozycje kontraktu dostawcy — co jest rozliczane i w jakiej jednostce. typ odnosi się do ops.blueprint_typy';
