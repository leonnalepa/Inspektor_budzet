-- %%
CREATE TABLE IF NOT EXISTS inspektor_budzet.rowkop.blueprint_reguly (
  rule_id      STRING NOT NULL,
  position_id  STRING,
  kolejnosc    INT,
  prog_od      DOUBLE,
  prog_do      DOUBLE,
  cena         DOUBLE,
  warunek      STRING,
  opis         STRING
)
COMMENT 'Reguły kalkulacji per pozycja — osobny wiersz na każdy próg lub warunek';
